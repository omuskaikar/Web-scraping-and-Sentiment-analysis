# %% [markdown]
# <a href="https://colab.research.google.com/github/omuskaikar/Web-scraping-and-Sentiment-analysis/blob/main/Beautiful%20soup%20scraping%20and%20Sentiment%20analysis%20from%20the%20scraped%20dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Web scraping and creating dataset

# %%
import requests
from bs4 import BeautifulSoup

# Scrape reviews from Flipkart
flipkart_base_url = "https://www.flipkart.com/apple-iphone-7-jet-black-128-gb/product-reviews/itmen6dakdgkpy6n?pid=MOBEMK62VCQ2UMT8&lid=LSTMOBEMK62VCQ2UMT8IY1JYN&sortOrder=MOST_HELPFUL&certifiedBuyer=false&aid=overall&page="

# Number of pages you want to scrape from Flipkart
num_pages = 5

flipkart_all_reviews = []

for page in range(1, num_pages+1):
    flipkart_url = flipkart_base_url + str(page)
    flipkart_response = requests.get(flipkart_url)
    flipkart_soup = BeautifulSoup(flipkart_response.text, "html.parser")
    flipkart_reviews = flipkart_soup.find_all("div", class_="_27M-vq")


    for review in flipkart_reviews:
        review_info = review.find_all("p", class_="_2sc7ZR")
        reviewer_name = review_info[0].text.strip()  # Scrape reviewer name
        review_title = review.find("p", class_="_2-N8zT").text.strip()
        review_paragraph = review.find("div", class_="t-ZTKy").text.strip()
        star_rating = review.find("div", class_="_3LWZlK").text.strip()
        review_date = review_info[1].text.strip()  # Scrape review date

        flipkart_all_reviews.append((reviewer_name, review_title, review_paragraph, star_rating, review_date))


print("Flipkart Reviews:")
for review in flipkart_all_reviews:
    print("Reviewer Name:", review[0])
    print("Review Title:", review[1])
    print("Review Paragraph:", review[2])
    print("Star Rating:", review[3])
    print("Review Date:", review[4])
    print()
# Out:
# Flipkart Reviews:
# Reviewer Name: SANCHIT NAGVENKAR
# Review Title: IF U DON'T HAVE AN IPHONE, WELL U DON'T AN IPHONE.
# Review Paragraph: The most awaited phone of the year. Being the iPhone 5S user for over 2 years, I just love the iPhone for its sturdy built and fabulous design. I've used all types of phone and operating system but this IOS is just awesome, the only phone which never lags or get hanged or restarts in between that's the best thing of apple's products. Got the phone delivered on 30/11/2016, which on time so no complaint on that. The product was delivered safely with no damage or any such other issues. It'...READ MORE
# Star Rating: 5
# Review Date: Dec, 2016
#
# Reviewer Name: Jaya Pahlajani
# Review Title: Horrible
# Review Paragraph: Mediocre product and service. The phone worked well for first 10 days but started heating while using and Charing after that. The battery takes 3 hrs to fully charge and same time to discharge. I am worried if it will explode in my hand. No help from flipkart or seller as it is past 10 days. So much so for a 60k product. Took a Long trip to service center to find there is a software problem, the phone was restored but problem persists. They say that heating is normal and we can only do some...READ MORE
# Star Rating: 1
# Review Date: Nov, 2016
#
# Reviewer Name: Flipkart Customer
# Review Title: TOOOO GOOOOOOD !!!!!!
# Review Paragraph: iphone 7 is superb as expected. I got upgraded myself from earlier version of iphone so i could feel the difference. But more importantly the Flipkart delivery has been excellent and highly impressive. They initially said to deliver by 8th, but preponed it to 7th evening and within 20 minutes of iphone's office launch in India, flipkart had it delivered to my home (by 7:20 pm on the 7th). Much faster than my friend got it at reliance outlet. Flipkart, hats off to you and your passionate tea...READ MORE
# Reviewer Name: K.S.RAJA
# Review Title: Simply awesome
# Review Paragraph: nice products thanks for flipkartREAD MORE
# Star Rating: 5
# Review Date: Nov, 2018
#
# Reviewer Name: CMR  Mohan
# Review Title: Wonderful
# Review Paragraph: excellent cameraREAD MORE
# Star Rating: 5
# Review Date: Feb, 2019
#
# Reviewer Name: Pia Lomdak
# Review Title: Perfect product!
# Review Paragraph: Very happy with the product as well as delivery Worth moneyREAD MORE
# Star Rating: 5
# Review Date: Sep, 2019
#
# Reviewer Name: Naeem Akhtar
# Review Title: Great product
# Review Paragraph: very nice phone. I'm very old Apple user that apple quality nothing comes any other brands. its too good really happy thanks filipkartREAD MORE
# Star Rating: 5
# Review Date: Nov, 2019
#
# Reviewer Name: Jay Nimavat
# Review Title: Best in the market!
# Review Paragraph: awesome product... speedy delivery before time by flipkart ... very happy thank u flipkartREAD MORE
# Star Rating: 5
# Review Date: Oct, 2019
#
# Reviewer Name: Sahil Nayak
# Review Title: Perfect product!
# Review Paragraph: What I say !!Love with this phone.Camera is just unbelievable.READ MORE
# Star Rating: 5
# Review Date: May, 2020
#
# Reviewer Name: Nijam  K
# Review Title: Perfect product!
# Review Paragraph: Excellent phoneREAD MORE
# Star Rating: 5
# Review Date: Oct, 2019

# %%
# %pip install selenium
# Out:
# Collecting selenium
#   Downloading selenium-4.13.0-py3-none-any.whl (9.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 58.9 MB/s eta 0:00:00
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in /usr/local/lib/python3.10/dist-packages (from selenium) (2.0.4)
# Collecting trio~=0.17 (from selenium)
#   Downloading trio-0.22.2-py3-none-any.whl (400 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.2/400.2 kB 42.1 MB/s eta 0:00:00
# Collecting trio-websocket~=0.9 (from selenium)
#   Downloading trio_websocket-0.11.1-py3-none-any.whl (17 kB)
# Requirement already satisfied: certifi>=2021.10.8 in /usr/local/lib/python3.10/dist-packages (from selenium) (2023.7.22)
# Requirement already satisfied: attrs>=20.1.0 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (23.1.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (3.4)
# Collecting outcome (from trio~=0.17->selenium)
#   Downloading outcome-1.2.0-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (1.1.3)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium)
#   Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Collecting h11<1,>=0.9.0 (from wsproto>=0.14->trio-websocket~=0.9->selenium)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.8 MB/s eta 0:00:00
# Installing collected packages: outcome, h11, wsproto, trio, trio-websocket, selenium
# Successfully installed h11-0.14.0 outcome-1.2.0 selenium-4.13.0 trio-0.22.2 trio-websocket-0.11.1 wsproto-1.2.0

# %%
# !pip install emoji
# !pip install selenium
# Out:
# Collecting emoji
#   Downloading emoji-2.7.0.tar.gz (361 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 361.8/361.8 kB 3.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: emoji
#   Building wheel for emoji (pyproject.toml) ... done
#   Created wheel for emoji: filename=emoji-2.7.0-py2.py3-none-any.whl size=356563 sha256=f2859b1fc0b394cdc5a807fa798ae77085b07c7f154d49d64ad6056f153ded22
#   Stored in directory: /root/.cache/pip/wheels/41/11/48/5df0b9727d5669c9174a141134f10304d1d78a3b89a4676f3d
# Successfully built emoji
# Installing collected packages: emoji
# Successfully installed emoji-2.7.0
# Collecting selenium
#   Downloading selenium-4.11.2-py3-none-any.whl (7.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 15.3 MB/s eta 0:00:00
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in /usr/local/lib/python3.10/dist-packages (from selenium) (1.26.16)
# Collecting trio~=0.17 (from selenium)
#   Downloading trio-0.22.2-py3-none-any.whl (400 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.2/400.2 kB 28.0 MB/s eta 0:00:00
# Collecting trio-websocket~=0.9 (from selenium)
#   Downloading trio_websocket-0.10.3-py3-none-any.whl (17 kB)
# Requirement already satisfied: certifi>=2021.10.8 in /usr/local/lib/python3.10/dist-packages (from selenium) (2023.7.22)
# Requirement already satisfied: attrs>=20.1.0 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (23.1.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (3.4)
# Collecting outcome (from trio~=0.17->selenium)
#   Downloading outcome-1.2.0-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (1.1.2)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium)
#   Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Collecting h11<1,>=0.9.0 (from wsproto>=0.14->trio-websocket~=0.9->selenium)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.9 MB/s eta 0:00:00
# Installing collected packages: outcome, h11, wsproto, trio, trio-websocket, selenium
# Successfully installed h11-0.14.0 outcome-1.2.0 selenium-4.11.2 trio-0.22.2 trio-websocket-0.10.3 wsproto-1.2.0

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import emoji

# Scrape reviews from Flipkart
flipkart_base_url = "https://www.flipkart.com/apple-iphone-7-jet-black-128-gb/product-reviews/itmen6dakdgkpy6n?pid=MOBEMK62VCQ2UMT8&lid=LSTMOBEMK62VCQ2UMT8IY1JYN&sortOrder=MOST_HELPFUL&certifiedBuyer=false&aid=overall&page="

# Number of pages you want to scrape from Flipkart
num_pages = 30

flipkart_all_reviews = []  # List to store all the reviews from Flipkart

for page in range(1, num_pages + 1):
    flipkart_url = flipkart_base_url + str(page)
    flipkart_response = requests.get(flipkart_url)
    flipkart_soup = BeautifulSoup(flipkart_response.text, "html.parser")
    flipkart_reviews = flipkart_soup.find_all("div", class_="_27M-vq")

    for review in flipkart_reviews:
        review_info = review.find_all("p", class_="_2sc7ZR")
        reviewer_name = review_info[0].text.strip()  # Scrape reviewer name
        review_title = review.find("p", class_="_2-N8zT").text.strip()

        # Extract review text, including hidden content
        review_text = review.find("div", class_="t-ZTKy").get_text(separator="\n").strip()

        star_rating = review.find("div", class_="_3LWZlK").text.strip()
        review_date = review_info[1].text.strip()  # Scrape review date
        review_text = emoji.demojize(review_text)

        flipkart_all_reviews.append((reviewer_name, review_title, review_text, star_rating, review_date))

# Create a DataFrame from the reviews
df = pd.DataFrame(flipkart_all_reviews, columns=["Reviewer Name", "Review Title", "Review Paragraph", "Star Rating", "Review Date"])

# %%
df
# Out:
#          Reviewer Name                                       Review Title  \
# 0    SANCHIT NAGVENKAR  IF U DON'T HAVE AN IPHONE, WELL U DON'T AN IPH...
# 1       Jaya Pahlajani                                           Horrible
# 2    Flipkart Customer                              TOOOO GOOOOOOD !!!!!!
# 3          Neeladri  V                                      Great product
# 4     Kiran Chaluvaiah                       Worthy upgrade from iPhone 6
# ..                 ...                                                ...
# 295       Chetan gupta                                              Kudos
# 296       Tanmay Joshi  Excellent product quality & condition by Flipkart
# 297  Flipkart Customer                                     Simply awesome
# 298   Gagandeep  singh                                            Awesome
# 299        Jaswant Raj                        Thanx flipkart for iphone 7
#
#                                       Review Paragraph Star Rating Review Date
# 0    The most awaited phone of the year. Being the ...           5   Dec, 2016
# 1    Mediocre product and service. The phone worked...           1   Nov, 2016
# 2    iphone 7 is superb as expected. I got upgraded...           5   Oct, 2016
# 3    Nice product . u will feel the difference.\nRE...           5   Jul, 2020
# 4    Firstly flipkart did a fair job on delivering ...           4   Oct, 2016
# ..                                                 ...         ...         ...
# 295  Ordered much hesitantly, seeing all the videos...           5   Jan, 2018
# 296  What an excellent phone!! Apple at its best, h...           5   Jan, 2018
# 297  No words excellent product.  Thank u soo much ...           5   Dec, 2017
# 298  This is my first Apple device and very happy t...           5   Dec, 2017
# 299  Thanks Flipkart everytime genuine product.i am...           5   Nov, 2017
#
# [300 rows x 5 columns]

# %%
df.to_csv('flipkart_reviews',index=False)

# %% [markdown]
# #Sentiment Analysis

# %%
import re
import nltk
import pandas as pd
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

df = pd.read_csv('/content/flipkart_reviews.csv')
# Download NLTK resources if not already downloaded
nltk.download('punkt')
nltk.download('stopwords')

def preprocess_text(text):
    text = text.lower()
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    return text

df['Processed Review Paragraph'] = df['Review Paragraph'].apply(preprocess_text)

# Tokenize and remove stopwords
stop_words = set(stopwords.words('english'))

def tokenize_and_remove_stopwords(text):
    tokens = word_tokenize(text)
    filtered_tokens = [word for word in tokens if word not in stop_words]
    return filtered_tokens

df['Processed Tokens'] = df['Processed Review Paragraph'].apply(tokenize_and_remove_stopwords)

# Print the DataFrame with the processed column
df
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
#           Reviewer Name                                       Review Title  \
# 0           Nitin Singh                                      Great product
# 1     Flipkart Customer                                      Great product
# 2            Neeladri V                                      Great product
# 3         Kishore Gagan                                          Brilliant
# 4     Flipkart Customer              Amazing service from Apple & Flipkart
# ...                 ...                                                ...
# 7022     Haresh Sachdev                     Delivered on launch day itself
# 7023      Ankit Ruparel                              Flipkart made my day!
# 7024         Swaroop SK  Review of my purchase of iphone7 through flipkart
# 7025       Zeelan Basha                                     Simply awesome
# 7026       Rohit Ranjan                                 Awesome experience
#
#                                        Review Paragraph  Star Rating  \
# 0                                             Great....            5
# 1     It's another solid performer from the apple st...            5
# 2            Nice product . u will feel the difference.            5
# 3                         Perfect mobile for iOS lovers            5
# 4     On Time Delivery Best Part Of Flipkart.\n\nAma...            5
# ...                                                 ...          ...
# 7022  Got the delivery on launch day itself. Thanks ...            5
# 7023  Last year Flipkart had lost me as a customer. ...            5
# 7024  I'm happy that I preordered iphone7 from flipk...            5
# 7025  IPhone 7 got it delivered much more early than...            5
# 7026          Nicely packaged and before time delivery.            5
#
#      Review Date                         Processed Review Paragraph  \
# 0      Mar, 2020                                              great
# 1      Oct, 2016  its another solid performer from the apple sta...
# 2      Jul, 2020           nice product  u will feel the difference
# 3      Feb, 2020                      perfect mobile for ios lovers
# 4      Oct, 2016  on time delivery best part of flipkart\n\namaz...
# ...          ...                                                ...
# 7022   Oct, 2016  got the delivery on launch day itself thanks f...
# 7023   Oct, 2016  last year flipkart had lost me as a customer i...
# 7024   Oct, 2016  im happy that i preordered iphone from flipkar...
# 7025   Oct, 2016  iphone  got it delivered much more early than ...
# 7026   Oct, 2016           nicely packaged and before time delivery
#
#                                        Processed Tokens
# 0                                               [great]
# 1     [another, solid, performer, apple, stable, unp...
# 2                  [nice, product, u, feel, difference]
# 3                        [perfect, mobile, ios, lovers]
# 4     [time, delivery, best, part, flipkart, amazing...
# ...                                                 ...
# 7022  [got, delivery, launch, day, thanks, flipkart,...
# 7023  [last, year, flipkart, lost, customer, cringed...
# 7024  [im, happy, preordered, iphone, flipkart, deli...
# 7025  [iphone, got, delivered, much, early, expected...
# 7026                 [nicely, packaged, time, delivery]
#
# [7027 rows x 7 columns]

# %%
df = df.sort_values(by='Star Rating', ascending=False)
df
# Out:
#           Reviewer Name                          Review Title  \
# 0           Nitin Singh                         Great product
# 4444  Flipkart Customer                        Simply awesome
# 4453            DEEPU S                           Good Device
# 4452      Ashwath Kumar                     Terrific purchase
# 4451      Pallavi Mitra            Amazing phone and delivery
# ...                 ...                                   ...
# 4276   Mohammed Shameer                     Absolute rubbish!
# 4277       Kiran Thomas            Production year 1year back
# 820   Flipkart Customer                Not recommended at all
# 6554  Flipkart Customer  Duplicate product or defective piece
# 2014      Darshan Rathi                              Horrible
#
#                                        Review Paragraph  Star Rating  \
# 0                                             Great....            5
# 4444                   Good product and smooth delivery            5
# 4453  Am very much glad about the flipkart offers th...            5
# 4452      nice product, excellent service from flipkart            5
# 4451  Its been a week I received the shipment. I was...            5
# ...                                                 ...          ...
# 4276  Charger not worked...when i contacted cc ...th...            1
# 4277                 1 year back product bad no quality            1
# 820                                          Nice phone            1
# 6554  Duplicate product ... camera quality is very b...            1
# 2014                               Phone is not working            1
#
#      Review Date                         Processed Review Paragraph  \
# 0      Mar, 2020                                              great
# 4444   Oct, 2017                   good product and smooth delivery
# 4453   Oct, 2017  am very much glad about the flipkart offers th...
# 4452   Oct, 2017       nice product excellent service from flipkart
# 4451   Oct, 2017  its been a week i received the shipment i was ...
# ...          ...                                                ...
# 4276   Oct, 2017  charger not workedwhen i contacted cc they are...
# 4277   Oct, 2017                   year back product bad no quality
# 820    Aug, 2020                                         nice phone
# 6554   Oct, 2017  duplicate product  camera quality is very bad ...
# 2014   Mar, 2020                               phone is not working
#
#                                        Processed Tokens
# 0                                               [great]
# 4444                  [good, product, smooth, delivery]
# 4453  [much, glad, flipkart, offers, got, iphone, de...
# 4452      [nice, product, excellent, service, flipkart]
# 4451  [week, received, shipment, loyal, android, use...
# ...                                                 ...
# 4276  [charger, workedwhen, contacted, cc, taking, i...
# 4277                [year, back, product, bad, quality]
# 820                                       [nice, phone]
# 6554  [duplicate, product, camera, quality, bad, get...
# 2014                                   [phone, working]
#
# [7027 rows x 7 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a figure with two subplots
plt.figure(figsize=(14, 6))

# Subplot 1: Countplot
plt.subplot(1, 2, 1)
sns.countplot(data=df, x='Star Rating', palette='Blues')  # Reverse blues color palette and set the order
plt.title('Distribution of Star Ratings')
plt.xlabel('Star Rating')
plt.ylabel('Count')

# Subplot 2: Pie Chart
plt.subplot(1, 2, 2)
star_counts = df['Star Rating'].value_counts()
plt.pie(star_counts, labels=star_counts.index, autopct='%1.1f%%', colors=sns.color_palette('Blues_r'), startangle=140)  # Reverse blues color palette
plt.title('Distribution of Star Ratings (Pie Chart)')
plt.legend(title="Star Ratings", labels=["5 Stars", "4 Stars", "3 Stars", "2 Stars", "1 Star"], loc='upper right')  # Adjust the legend position

# Adjust layout
plt.tight_layout()

# Show the plots
plt.show()

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# True

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import pandas as pd

# Initialize the VADER sentiment analyzer
sid = SentimentIntensityAnalyzer()

# Calculate sentiment scores and categorize sentiment
def get_sentiment_score(text):
    sentiment_scores = sid.polarity_scores(text)
    return sentiment_scores

# Apply the sentiment analysis function to the processed review paragraphs
df['Sentiment Scores'] = df['Processed Review Paragraph'].apply(get_sentiment_score)

# Function to categorize sentiment
def categorize_sentiment(sentiment_scores):
    compound_score = sentiment_scores['compound']
    if compound_score >= 0.05:
        return 'Positive'
    elif compound_score <= -0.05:
        return 'Negative'
    else:
        return 'Neutral'

# Apply sentiment categorization to the sentiment scores
df['Sentiment'] = df['Sentiment Scores'].apply(categorize_sentiment)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Define custom colors for sentiment categories
colors = {'Positive': 'blue', 'Negative': 'red', 'Neutral': 'green'}

# Create a figure with two subplots
plt.figure(figsize=(14, 6))

# Subplot 1: Countplot for Sentiment Distribution
plt.subplot(1, 2, 1)
sns.countplot(data=df, x='Sentiment', palette=colors.values())
plt.title('Distribution of Sentiments')
plt.xlabel('Sentiment')
plt.ylabel('Count')

# Subplot 2: Pie Chart for Sentiment Distribution
plt.subplot(1, 2, 2)
sentiment_counts = df['Sentiment'].value_counts()
plt.pie(sentiment_counts, labels=sentiment_counts.index, autopct='%1.1f%%', colors=[colors[s] for s in sentiment_counts.index], startangle=140)
plt.title('Distribution of Sentiments (Pie Chart)')
plt.legend(title="Sentiments", labels=["Positive", "Negative", "Neutral"], loc='upper right')

# Adjust layout
plt.tight_layout()

# Show the plots
plt.show()
